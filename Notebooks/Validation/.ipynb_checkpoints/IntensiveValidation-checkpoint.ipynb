# %%
library(tidyverse)

# %%
path = "/home/and/RIDIR/Code/Validation/"
dataset = "Source2000/"
spark_intensive = read_tsv(paste0(path, dataset, "geospark_intensive.tsv"), col_names = F) %>%
    rename(tid = X1, spark = X2) %>%
    arrange(tid)

spark_intensive %>% show
# Out:
# Parsed with column specification:
# cols(
#   X1 = col_character(),
#   X2 = col_double()
# )
# # A tibble: 366 x 2
#    tid          spark
#    <chr>        <dbl>
#  1 T42101000001 1.32
#  2 T42101000002 0.461
#  3 T42101000003 3.77
#  4 T42101000004 0.939
#  5 T42101000005 0.135
#  6 T42101000006 0.609
#  7 T42101000007 1.33
#  8 T42101000008 2.38
#  9 T42101000009 1.12
# 10 T42101000010 4.69
# # … with 356 more rows

# %%
pandas_intensive = read_tsv(paste0(path, dataset, "geopandas_intensive.tsv"), col_names = F) %>%
    rename(tid = X1, pandas = X2) %>%
    arrange(tid)

pandas_intensive %>% show
# Out:
# Parsed with column specification:
# cols(
#   X1 = col_character(),
#   X2 = col_double()
# )
# # A tibble: 367 x 2
#    tid          pandas
#    <chr>         <dbl>
#  1 T42101000001  1.32
#  2 T42101000002  0.461
#  3 T42101000003  3.77
#  4 T42101000004  0.941
#  5 T42101000005  0.135
#  6 T42101000006  0.609
#  7 T42101000007  1.33
#  8 T42101000008  2.38
#  9 T42101000009  1.12
# 10 T42101000010  4.69
# # … with 357 more rows

# %%
joined = pandas_intensive %>% inner_join(spark_intensive, by="tid")
joined %>% show
# Out:
# # A tibble: 366 x 3
#    tid          pandas spark
#    <chr>         <dbl> <dbl>
#  1 T42101000001  1.32  1.32
#  2 T42101000002  0.461 0.461
#  3 T42101000003  3.77  3.77
#  4 T42101000004  0.941 0.939
#  5 T42101000005  0.135 0.135
#  6 T42101000006  0.609 0.609
#  7 T42101000007  1.33  1.33
#  8 T42101000008  2.38  2.38
#  9 T42101000009  1.12  1.12
# 10 T42101000010  4.69  4.69
# # … with 356 more rows

# %%
ggplot(data = joined, aes(x = pandas, y = spark)) + geom_point()
# Out:
# plot without title

# %%
library(MLmetrics)

print(paste("R2:  ", R2_Score(joined$spark, joined$pandas)))
print(paste("RMSE:", RMSE(joined$spark, joined$pandas)))
print(paste("MAE: ", MAE(joined$spark, joined$pandas)))
print(paste("MSE: ", MSE(joined$spark, joined$pandas)))
# Out:
# [1] "R2:   0.979943719396579"
# [1] "RMSE: 0.926570198932923"
# [1] "MAE:  0.119453175632082"
# [1] "MSE:  0.858532333550596"

# %%
dataset = "Source2010/"
spark_intensive = read_tsv(paste0(path, dataset, "geospark_intensive.tsv"), col_names = F) %>%
    rename(tid = X1, spark = X2) %>%
    arrange(tid)
pandas_intensive = read_tsv(paste0(path, dataset, "geopandas_intensive.tsv"), col_names = F) %>%
    rename(tid = X1, pandas = X2) %>%
    arrange(tid)
joined =  pandas_intensive %>% inner_join(spark_intensive, by="tid")
ggplot(data = joined, aes(x = pandas, y = spark)) + geom_point()
# Out:
# Parsed with column specification:
# cols(
#   X1 = col_character(),
#   X2 = col_double()
# )
# Parsed with column specification:
# cols(
#   X1 = col_character(),
#   X2 = col_double()
# )
# plot without title

# %%
print(paste("R2:  ", R2_Score(joined$spark, joined$pandas)))
print(paste("RMSE:", RMSE(joined$spark, joined$pandas)))
print(paste("MAE: ", MAE(joined$spark, joined$pandas)))
print(paste("MSE: ", MSE(joined$spark, joined$pandas)))
# Out:
# [1] "R2:   0.9525664004843"
# [1] "RMSE: 0.978576379182994"
# [1] "MAE:  0.153533971329394"
# [1] "MSE:  0.957611729894899"
